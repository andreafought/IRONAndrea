# %% [markdown]
#  ### Sending requests

# %%
import requests

google = requests.get("https://developers.google.com")
print("Google:", google.status_code)

NBA = requests.get("https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason")
print("NBA:", NBA.status_code)

rotten_tomato = requests.get("http://api.rottentomatoes.com/api/public/v1.0/lists/movies/box_office.json")
print("Rotten Tomatoes:", rotten_tomato.status_code)
# Out:
# Google: 200
# NBA: 401
# Rotten Tomatoes: 403

# %% [markdown]
# ### json response

# %%
# install json on python if needed
import json

response = requests.get("https://jsonplaceholder.typicode.com/todos")
results = response.json()
results
# Out:
# [{'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False},
#  {'userId': 1,
#   'id': 2,
#   'title': 'quis ut nam facilis et officia qui',
#   'completed': False},
#  {'userId': 1, 'id': 3, 'title': 'fugiat veniam minus', 'completed': False},
#  {'userId': 1, 'id': 4, 'title': 'et porro tempora', 'completed': True},
#  {'userId': 1,
#   'id': 5,
#   'title': 'laboriosam mollitia et enim quasi adipisci quia provident illum',
#   'completed': False},
#  {'userId': 1,
#   'id': 6,
#   'title': 'qui ullam ratione quibusdam voluptatem quia omnis',
#   'completed': False},
#  {'userId': 1,
#   'id': 7,
#   'title': 'illo expedita consequatur quia in',
#   'completed': False},
#  {'userId': 1,
#   'id': 8,
#   'title': 'quo adipisci enim quam ut ab',
#   'completed': True},
#  {'userId': 1,
#   'id': 9,
#   'title': 'molestiae perspiciatis ipsa',
#   'completed': False},
#  {'userId': 1,
#   'id': 10,
#   'title': 'illo est ratione doloremque quia maiores aut',
#   'completed': True},
#  {'userId': 1,
#   'id': 11,
#   'title': 'vero rerum temporibus dolor',
#   'completed': True},
#  {'userId': 1,
#   'id': 12,
#   'title': 'ipsa repellendus fugit nisi',
#   'completed': True},
#  {'userId': 1, 'id': 13, 'title': 'et doloremque nulla', 'completed': False},
#  {'userId': 1,
#   'id': 14,
#   'title': 'repellendus sunt dolores architecto voluptatum',
#   'completed': True},
#  {'userId': 1,
#   'id': 15,
#   'title': 'ab voluptatum amet voluptas',
#   'completed': True},
#  {'userId': 1,
#   'id': 16,
#   'title': 'accusamus eos facilis sint et aut voluptatem',
#   'completed': True},
#  {'userId': 1,
#   'id': 17,
#   'title': 'quo laboriosam deleniti aut qui',
#   'completed': True},
#  {'userId': 1,
#   'id': 18,
#   'title': 'dolorum est consequatur ea mollitia in culpa',
#   'completed': False},
#  {'userId': 1,
#   'id': 19,
#   'title': 'molestiae ipsa aut voluptatibus pariatur dolor nihil',
#   'completed': True},
#  {'userId': 1,
#   'id': 20,
#   'title': 'ullam nobis libero sapiente ad optio sint',
#   'completed': True},
#  {'userId': 2,
#   'id': 21,
#   'title': 'suscipit repellat esse quibusdam voluptatem incidunt',
#   'completed': False},
#  {'userId': 2,
#   'id': 22,
#   'title': 'distinctio vitae autem nihil ut molestias quo',
#   'completed': True},
#  {'userId': 2,
#   'id': 23,
#   'title': 'et itaque necessitatibus maxime molestiae qui quas velit',
#   'completed': False},
#  {'userId': 2,
#   'id': 24,
#   'title': 'adipisci non ad dicta qui amet quaerat doloribus ea',
#   'completed': False},
#  {'userId': 2,
#   'id': 25,
#   'title': 'voluptas quo tenetur perspiciatis explicabo natus',
#   'completed': True},
#  {'userId': 2, 'id': 26, 'title': 'aliquam aut quasi', 'completed': True},
#  {'userId': 2,
#   'id': 27,
#   'title': 'veritatis pariatur delectus',
#   'completed': True},
#  {'userId': 2,
#   'id': 28,
#   'title': 'nesciunt totam sit blanditiis sit',
#   'completed': False},
#  {'userId': 2, 'id': 29, 'title': 'laborum aut in quam', 'completed': False},
#  {'userId': 2,
#   'id': 30,
#   'title': 'nemo perspiciatis repellat ut dolor libero commodi blanditiis omnis',
#   'completed': True},
#  {'userId': 2,
#   'id': 31,
#   'title': 'repudiandae totam in est sint facere fuga',
#   'completed': False},
#  {'userId': 2,
#   'id': 32,
#   'title': 'earum doloribus ea doloremque quis',
#   'completed': False},
#  {'userId': 2, 'id': 33, 'title': 'sint sit aut vero', 'completed': False},
#  {'userId': 2,
#   'id': 34,
#   'title': 'porro aut necessitatibus eaque distinctio',
#   'completed': False},
#  {'userId': 2,
#   'id': 35,
#   'title': 'repellendus veritatis molestias dicta incidunt',
#   'completed': True},
#  {'userId': 2,
#   'id': 36,
#   'title': 'excepturi deleniti adipisci voluptatem et neque optio illum ad',
#   'completed': True},
#  {'userId': 2, 'id': 37, 'title': 'sunt cum tempora', 'completed': False},
#  {'userId': 2, 'id': 38, 'title': 'totam quia non', 'completed': False},
#  {'userId': 2,
#   'id': 39,
#   'title': 'doloremque quibusdam asperiores libero corrupti illum qui omnis',
#   'completed': False},
#  {'userId': 2,
#   'id': 40,
#   'title': 'totam atque quo nesciunt',
#   'completed': True},
#  {'userId': 3,
#   'id': 41,
#   'title': 'aliquid amet impedit consequatur aspernatur placeat eaque fugiat suscipit',
#   'completed': False},
#  {'userId': 3,
#   'id': 42,
#   'title': 'rerum perferendis error quia ut eveniet',
#   'completed': False},
#  {'userId': 3,
#   'id': 43,
#   'title': 'tempore ut sint quis recusandae',
#   'completed': True},
#  {'userId': 3,
#   'id': 44,
#   'title': 'cum debitis quis accusamus doloremque ipsa natus sapiente omnis',
#   'completed': True},
#  {'userId': 3,
#   'id': 45,
#   'title': 'velit soluta adipisci molestias reiciendis harum',
#   'completed': False},
#  {'userId': 3,
#   'id': 46,
#   'title': 'vel voluptatem repellat nihil placeat corporis',
#   'completed': False},
#  {'userId': 3,
#   'id': 47,
#   'title': 'nam qui rerum fugiat accusamus',
#   'completed': False},
#  {'userId': 3,
#   'id': 48,
#   'title': 'sit reprehenderit omnis quia',
#   'completed': False},
#  {'userId': 3,
#   'id': 49,
#   'title': 'ut necessitatibus aut maiores debitis officia blanditiis velit et',
#   'completed': False},
#  {'userId': 3,
#   'id': 50,
#   'title': 'cupiditate necessitatibus ullam aut quis dolor voluptate',
#   'completed': True},
#  {'userId': 3,
#   'id': 51,
#   'title': 'distinctio exercitationem ab doloribus',
#   'completed': False},
#  {'userId': 3,
#   'id': 52,
#   'title': 'nesciunt dolorum quis recusandae ad pariatur ratione',
#   'completed': False},
#  {'userId': 3,
#   'id': 53,
#   'title': 'qui labore est occaecati recusandae aliquid quam',
#   'completed': False},
#  {'userId': 3,
#   'id': 54,
#   'title': 'quis et est ut voluptate quam dolor',
#   'completed': True},
#  {'userId': 3,
#   'id': 55,
#   'title': 'voluptatum omnis minima qui occaecati provident nulla voluptatem ratione',
#   'completed': True},
#  {'userId': 3,
#   'id': 56,
#   'title': 'deleniti ea temporibus enim',
#   'completed': True},
#  {'userId': 3,
#   'id': 57,
#   'title': 'pariatur et magnam ea doloribus similique voluptatem rerum quia',
#   'completed': False},
#  {'userId': 3,
#   'id': 58,
#   'title': 'est dicta totam qui explicabo doloribus qui dignissimos',
#   'completed': False},
#  {'userId': 3,
#   'id': 59,
#   'title': 'perspiciatis velit id laborum placeat iusto et aliquam odio',
#   'completed': False},
#  {'userId': 3,
#   'id': 60,
#   'title': 'et sequi qui architecto ut adipisci',
#   'completed': True},
#  {'userId': 4,
#   'id': 61,
#   'title': 'odit optio omnis qui sunt',
#   'completed': True},
#  {'userId': 4,
#   'id': 62,
#   'title': 'et placeat et tempore aspernatur sint numquam',
#   'completed': False},
#  {'userId': 4,
#   'id': 63,
#   'title': 'doloremque aut dolores quidem fuga qui nulla',
#   'completed': True},
#  {'userId': 4,
#   'id': 64,
#   'title': 'voluptas consequatur qui ut quia magnam nemo esse',
#   'completed': False},
#  {'userId': 4,
#   'id': 65,
#   'title': 'fugiat pariatur ratione ut asperiores necessitatibus magni',
#   'completed': False},
#  {'userId': 4,
#   'id': 66,
#   'title': 'rerum eum molestias autem voluptatum sit optio',
#   'completed': False},
#  {'userId': 4,
#   'id': 67,
#   'title': 'quia voluptatibus voluptatem quos similique maiores repellat',
#   'completed': False},
#  {'userId': 4,
#   'id': 68,
#   'title': 'aut id perspiciatis voluptatem iusto',
#   'completed': False},
#  {'userId': 4,
#   'id': 69,
#   'title': 'doloribus sint dolorum ab adipisci itaque dignissimos aliquam suscipit',
#   'completed': False},
#  {'userId': 4,
#   'id': 70,
#   'title': 'ut sequi accusantium et mollitia delectus sunt',
#   'completed': False},
#  {'userId': 4, 'id': 71, 'title': 'aut velit saepe ullam', 'completed': False},
#  {'userId': 4,
#   'id': 72,
#   'title': 'praesentium facilis facere quis harum voluptatibus voluptatem eum',
#   'completed': False},
#  {'userId': 4,
#   'id': 73,
#   'title': 'sint amet quia totam corporis qui exercitationem commodi',
#   'completed': True},
#  {'userId': 4,
#   'id': 74,
#   'title': 'expedita tempore nobis eveniet laborum maiores',
#   'completed': False},
#  {'userId': 4,
#   'id': 75,
#   'title': 'occaecati adipisci est possimus totam',
#   'completed': False},
#  {'userId': 4, 'id': 76, 'title': 'sequi dolorem sed', 'completed': True},
#  {'userId': 4,
#   'id': 77,
#   'title': 'maiores aut nesciunt delectus exercitationem vel assumenda eligendi at',
#   'completed': False},
#  {'userId': 4,
#   'id': 78,
#   'title': 'reiciendis est magnam amet nemo iste recusandae impedit quaerat',
#   'completed': False},
#  {'userId': 4, 'id': 79, 'title': 'eum ipsa maxime ut', 'completed': True},
#  {'userId': 4,
#   'id': 80,
#   'title': 'tempore molestias dolores rerum sequi voluptates ipsum consequatur',
#   'completed': True},
#  {'userId': 5, 'id': 81, 'title': 'suscipit qui totam', 'completed': True},
#  {'userId': 5,
#   'id': 82,
#   'title': 'voluptates eum voluptas et dicta',
#   'completed': False},
#  {'userId': 5,
#   'id': 83,
#   'title': 'quidem at rerum quis ex aut sit quam',
#   'completed': True},
#  {'userId': 5,
#   'id': 84,
#   'title': 'sunt veritatis ut voluptate',
#   'completed': False},
#  {'userId': 5, 'id': 85, 'title': 'et quia ad iste a', 'completed': True},
#  {'userId': 5,
#   'id': 86,
#   'title': 'incidunt ut saepe autem',
#   'completed': True},
#  {'userId': 5,
#   'id': 87,
#   'title': 'laudantium quae eligendi consequatur quia et vero autem',
#   'completed': True},
#  {'userId': 5,
#   'id': 88,
#   'title': 'vitae aut excepturi laboriosam sint aliquam et et accusantium',
#   'completed': False},
#  {'userId': 5, 'id': 89, 'title': 'sequi ut omnis et', 'completed': True},
#  {'userId': 5,
#   'id': 90,
#   'title': 'molestiae nisi accusantium tenetur dolorem et',
#   'completed': True},
#  {'userId': 5,
#   'id': 91,
#   'title': 'nulla quis consequatur saepe qui id expedita',
#   'completed': True},
#  {'userId': 5, 'id': 92, 'title': 'in omnis laboriosam', 'completed': True},
#  {'userId': 5,
#   'id': 93,
#   'title': 'odio iure consequatur molestiae quibusdam necessitatibus quia sint',
#   'completed': True},
#  {'userId': 5,
#   'id': 94,
#   'title': 'facilis modi saepe mollitia',
#   'completed': False},
#  {'userId': 5,
#   'id': 95,
#   'title': 'vel nihil et molestiae iusto assumenda nemo quo ut',
#   'completed': True},
#  {'userId': 5,
#   'id': 96,
#   'title': 'nobis suscipit ducimus enim asperiores voluptas',
#   'completed': False},
#  {'userId': 5,
#   'id': 97,
#   'title': 'dolorum laboriosam eos qui iure aliquam',
#   'completed': False},
#  {'userId': 5,
#   'id': 98,
#   'title': 'debitis accusantium ut quo facilis nihil quis sapiente necessitatibus',
#   'completed': True},
#  {'userId': 5,
#   'id': 99,
#   'title': 'neque voluptates ratione',
#   'completed': False},
#  {'userId': 5,
#   'id': 100,
#   'title': 'excepturi a et neque qui expedita vel voluptate',
#   'completed': False},
#  {'userId': 6,
#   'id': 101,
#   'title': 'explicabo enim cumque porro aperiam occaecati minima',
#   'completed': False},
#  {'userId': 6, 'id': 102, 'title': 'sed ab consequatur', 'completed': False},
#  {'userId': 6,
#   'id': 103,
#   'title': 'non sunt delectus illo nulla tenetur enim omnis',
#   'completed': False},
#  {'userId': 6,
#   'id': 104,
#   'title': 'excepturi non laudantium quo',
#   'completed': False},
#  {'userId': 6,
#   'id': 105,
#   'title': 'totam quia dolorem et illum repellat voluptas optio',
#   'completed': True},
#  {'userId': 6,
#   'id': 106,
#   'title': 'ad illo quis voluptatem temporibus',
#   'completed': True},
#  {'userId': 6,
#   'id': 107,
#   'title': 'praesentium facilis omnis laudantium fugit ad iusto nihil nesciunt',
#   'completed': False},
#  {'userId': 6,
#   'id': 108,
#   'title': 'a eos eaque nihil et exercitationem incidunt delectus',
#   'completed': True},
#  {'userId': 6,
#   'id': 109,
#   'title': 'autem temporibus harum quisquam in culpa',
#   'completed': True},
#  {'userId': 6, 'id': 110, 'title': 'aut aut ea corporis', 'completed': True},
#  {'userId': 6,
#   'id': 111,
#   'title': 'magni accusantium labore et id quis provident',
#   'completed': False},
#  {'userId': 6,
#   'id': 112,
#   'title': 'consectetur impedit quisquam qui deserunt non rerum consequuntur eius',
#   'completed': False},
#  {'userId': 6,
#   'id': 113,
#   'title': 'quia atque aliquam sunt impedit voluptatum rerum assumenda nisi',
#   'completed': False},
#  {'userId': 6,
#   'id': 114,
#   'title': 'cupiditate quos possimus corporis quisquam exercitationem beatae',
#   'completed': False},
#  {'userId': 6, 'id': 115, 'title': 'sed et ea eum', 'completed': False},
#  {'userId': 6,
#   'id': 116,
#   'title': 'ipsa dolores vel facilis ut',
#   'completed': True},
#  {'userId': 6,
#   'id': 117,
#   'title': 'sequi quae est et qui qui eveniet asperiores',
#   'completed': False},
#  {'userId': 6,
#   'id': 118,
#   'title': 'quia modi consequatur vero fugiat',
#   'completed': False},
#  {'userId': 6,
#   'id': 119,
#   'title': 'corporis ducimus ea perspiciatis iste',
#   'completed': False},
#  {'userId': 6,
#   'id': 120,
#   'title': 'dolorem laboriosam vel voluptas et aliquam quasi',
#   'completed': False},
#  {'userId': 7,
#   'id': 121,
#   'title': 'inventore aut nihil minima laudantium hic qui omnis',
#   'completed': True},
#  {'userId': 7,
#   'id': 122,
#   'title': 'provident aut nobis culpa',
#   'completed': True},
#  {'userId': 7,
#   'id': 123,
#   'title': 'esse et quis iste est earum aut impedit',
#   'completed': False},
#  {'userId': 7, 'id': 124, 'title': 'qui consectetur id', 'completed': False},
#  {'userId': 7,
#   'id': 125,
#   'title': 'aut quasi autem iste tempore illum possimus',
#   'completed': False},
#  {'userId': 7,
#   'id': 126,
#   'title': 'ut asperiores perspiciatis veniam ipsum rerum saepe',
#   'completed': True},
#  {'userId': 7,
#   'id': 127,
#   'title': 'voluptatem libero consectetur rerum ut',
#   'completed': True},
#  {'userId': 7,
#   'id': 128,
#   'title': 'eius omnis est qui voluptatem autem',
#   'completed': False},
#  {'userId': 7,
#   'id': 129,
#   'title': 'rerum culpa quis harum',
#   'completed': False},
#  {'userId': 7,
#   'id': 130,
#   'title': 'nulla aliquid eveniet harum laborum libero alias ut unde',
#   'completed': True},
#  {'userId': 7, 'id': 131, 'title': 'qui ea incidunt quis', 'completed': False},
#  {'userId': 7,
#   'id': 132,
#   'title': 'qui molestiae voluptatibus velit iure harum quisquam',
#   'completed': True},
#  {'userId': 7,
#   'id': 133,
#   'title': 'et labore eos enim rerum consequatur sunt',
#   'completed': True},
#  {'userId': 7,
#   'id': 134,
#   'title': 'molestiae doloribus et laborum quod ea',
#   'completed': False},
#  {'userId': 7,
#   'id': 135,
#   'title': 'facere ipsa nam eum voluptates reiciendis vero qui',
#   'completed': False},
#  {'userId': 7,
#   'id': 136,
#   'title': 'asperiores illo tempora fuga sed ut quasi adipisci',
#   'completed': False},
#  {'userId': 7, 'id': 137, 'title': 'qui sit non', 'completed': False},
#  {'userId': 7,
#   'id': 138,
#   'title': 'placeat minima consequatur rem qui ut',
#   'completed': True},
#  {'userId': 7,
#   'id': 139,
#   'title': 'consequatur doloribus id possimus voluptas a voluptatem',
#   'completed': False},
#  {'userId': 7,
#   'id': 140,
#   'title': 'aut consectetur in blanditiis deserunt quia sed laboriosam',
#   'completed': True},
#  {'userId': 8,
#   'id': 141,
#   'title': 'explicabo consectetur debitis voluptates quas quae culpa rerum non',
#   'completed': True},
#  {'userId': 8,
#   'id': 142,
#   'title': 'maiores accusantium architecto necessitatibus reiciendis ea aut',
#   'completed': True},
#  {'userId': 8,
#   'id': 143,
#   'title': 'eum non recusandae cupiditate animi',
#   'completed': False},
#  {'userId': 8,
#   'id': 144,
#   'title': 'ut eum exercitationem sint',
#   'completed': False},
#  {'userId': 8,
#   'id': 145,
#   'title': 'beatae qui ullam incidunt voluptatem non nisi aliquam',
#   'completed': False},
#  {'userId': 8,
#   'id': 146,
#   'title': 'molestiae suscipit ratione nihil odio libero impedit vero totam',
#   'completed': True},
#  {'userId': 8,
#   'id': 147,
#   'title': 'eum itaque quod reprehenderit et facilis dolor autem ut',
#   'completed': True},
#  {'userId': 8,
#   'id': 148,
#   'title': 'esse quas et quo quasi exercitationem',
#   'completed': False},
#  {'userId': 8,
#   'id': 149,
#   'title': 'animi voluptas quod perferendis est',
#   'completed': False},
#  {'userId': 8,
#   'id': 150,
#   'title': 'eos amet tempore laudantium fugit a',
#   'completed': False},
#  {'userId': 8,
#   'id': 151,
#   'title': 'accusamus adipisci dicta qui quo ea explicabo sed vero',
#   'completed': True},
#  {'userId': 8,
#   'id': 152,
#   'title': 'odit eligendi recusandae doloremque cumque non',
#   'completed': False},
#  {'userId': 8,
#   'id': 153,
#   'title': 'ea aperiam consequatur qui repellat eos',
#   'completed': False},
#  {'userId': 8, 'id': 154, 'title': 'rerum non ex sapiente', 'completed': True},
#  {'userId': 8,
#   'id': 155,
#   'title': 'voluptatem nobis consequatur et assumenda magnam',
#   'completed': True},
#  {'userId': 8,
#   'id': 156,
#   'title': 'nam quia quia nulla repellat assumenda quibusdam sit nobis',
#   'completed': True},
#  {'userId': 8,
#   'id': 157,
#   'title': 'dolorem veniam quisquam deserunt repellendus',
#   'completed': True},
#  {'userId': 8,
#   'id': 158,
#   'title': 'debitis vitae delectus et harum accusamus aut deleniti a',
#   'completed': True},
#  {'userId': 8,
#   'id': 159,
#   'title': 'debitis adipisci quibusdam aliquam sed dolore ea praesentium nobis',
#   'completed': True},
#  {'userId': 8,
#   'id': 160,
#   'title': 'et praesentium aliquam est',
#   'completed': False},
#  {'userId': 9,
#   'id': 161,
#   'title': 'ex hic consequuntur earum omnis alias ut occaecati culpa',
#   'completed': True},
#  {'userId': 9,
#   'id': 162,
#   'title': 'omnis laboriosam molestias animi sunt dolore',
#   'completed': True},
#  {'userId': 9,
#   'id': 163,
#   'title': 'natus corrupti maxime laudantium et voluptatem laboriosam odit',
#   'completed': False},
#  {'userId': 9,
#   'id': 164,
#   'title': 'reprehenderit quos aut aut consequatur est sed',
#   'completed': False},
#  {'userId': 9,
#   'id': 165,
#   'title': 'fugiat perferendis sed aut quidem',
#   'completed': False},
#  {'userId': 9,
#   'id': 166,
#   'title': 'quos quo possimus suscipit minima ut',
#   'completed': False},
#  {'userId': 9,
#   'id': 167,
#   'title': 'et quis minus quo a asperiores molestiae',
#   'completed': False},
#  {'userId': 9,
#   'id': 168,
#   'title': 'recusandae quia qui sunt libero',
#   'completed': False},
#  {'userId': 9,
#   'id': 169,
#   'title': 'ea odio perferendis officiis',
#   'completed': True},
#  {'userId': 9,
#   'id': 170,
#   'title': 'quisquam aliquam quia doloribus aut',
#   'completed': False},
#  {'userId': 9,
#   'id': 171,
#   'title': 'fugiat aut voluptatibus corrupti deleniti velit iste odio',
#   'completed': True},
#  {'userId': 9,
#   'id': 172,
#   'title': 'et provident amet rerum consectetur et voluptatum',
#   'completed': False},
#  {'userId': 9,
#   'id': 173,
#   'title': 'harum ad aperiam quis',
#   'completed': False},
#  {'userId': 9, 'id': 174, 'title': 'similique aut quo', 'completed': False},
#  {'userId': 9,
#   'id': 175,
#   'title': 'laudantium eius officia perferendis provident perspiciatis asperiores',
#   'completed': True},
#  {'userId': 9,
#   'id': 176,
#   'title': 'magni soluta corrupti ut maiores rem quidem',
#   'completed': False},
#  {'userId': 9,
#   'id': 177,
#   'title': 'et placeat temporibus voluptas est tempora quos quibusdam',
#   'completed': False},
#  {'userId': 9,
#   'id': 178,
#   'title': 'nesciunt itaque commodi tempore',
#   'completed': True},
#  {'userId': 9,
#   'id': 179,
#   'title': 'omnis consequuntur cupiditate impedit itaque ipsam quo',
#   'completed': True},
#  {'userId': 9,
#   'id': 180,
#   'title': 'debitis nisi et dolorem repellat et',
#   'completed': True},
#  {'userId': 10,
#   'id': 181,
#   'title': 'ut cupiditate sequi aliquam fuga maiores',
#   'completed': False},
#  {'userId': 10,
#   'id': 182,
#   'title': 'inventore saepe cumque et aut illum enim',
#   'completed': True},
#  {'userId': 10,
#   'id': 183,
#   'title': 'omnis nulla eum aliquam distinctio',
#   'completed': True},
#  {'userId': 10,
#   'id': 184,
#   'title': 'molestias modi perferendis perspiciatis',
#   'completed': False},
#  {'userId': 10,
#   'id': 185,
#   'title': 'voluptates dignissimos sed doloribus animi quaerat aut',
#   'completed': False},
#  {'userId': 10,
#   'id': 186,
#   'title': 'explicabo odio est et',
#   'completed': False},
#  {'userId': 10,
#   'id': 187,
#   'title': 'consequuntur animi possimus',
#   'completed': False},
#  {'userId': 10, 'id': 188, 'title': 'vel non beatae est', 'completed': True},
#  {'userId': 10,
#   'id': 189,
#   'title': 'culpa eius et voluptatem et',
#   'completed': True},
#  {'userId': 10,
#   'id': 190,
#   'title': 'accusamus sint iusto et voluptatem exercitationem',
#   'completed': True},
#  {'userId': 10,
#   'id': 191,
#   'title': 'temporibus atque distinctio omnis eius impedit tempore molestias pariatur',
#   'completed': True},
#  {'userId': 10,
#   'id': 192,
#   'title': 'ut quas possimus exercitationem sint voluptates',
#   'completed': False},
#  {'userId': 10,
#   'id': 193,
#   'title': 'rerum debitis voluptatem qui eveniet tempora distinctio a',
#   'completed': True},
#  {'userId': 10,
#   'id': 194,
#   'title': 'sed ut vero sit molestiae',
#   'completed': False},
#  {'userId': 10,
#   'id': 195,
#   'title': 'rerum ex veniam mollitia voluptatibus pariatur',
#   'completed': True},
#  {'userId': 10,
#   'id': 196,
#   'title': 'consequuntur aut ut fugit similique',
#   'completed': True},
#  {'userId': 10,
#   'id': 197,
#   'title': 'dignissimos quo nobis earum saepe',
#   'completed': True},
#  {'userId': 10,
#   'id': 198,
#   'title': 'quis eius est sint explicabo',
#   'completed': True},
#  {'userId': 10,
#   'id': 199,
#   'title': 'numquam repellendus a magnam',
#   'completed': True},
#  {'userId': 10,
#   'id': 200,
#   'title': 'ipsam aperiam voluptates qui',
#   'completed': False}]

# %%
import pandas as pd
# json to pandas dataframe
data = pd.DataFrame.from_dict(results)

# %%
data
# Out:
#      userId   id                                              title  completed
# 0         1    1                                 delectus aut autem      False
# 1         1    2                 quis ut nam facilis et officia qui      False
# 2         1    3                                fugiat veniam minus      False
# 3         1    4                                   et porro tempora       True
# 4         1    5  laboriosam mollitia et enim quasi adipisci qui...      False
# ..      ...  ...                                                ...        ...
# 195      10  196                consequuntur aut ut fugit similique       True
# 196      10  197                  dignissimos quo nobis earum saepe       True
# 197      10  198                       quis eius est sint explicabo       True
# 198      10  199                       numquam repellendus a magnam       True
# 199      10  200                       ipsam aperiam voluptates qui      False
#
# [200 rows x 4 columns]

# %% [markdown]
# ### GitHub API
#
# Docs here: https://docs.github.com/en/free-pro-team@latest/rest/reference/activity

# %%
response = requests.get('https://api.github.com/users/andreafought/events/public')
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# [{'id': '17042971853',
#   'type': 'PushEvent',
#   'actor': {'id': 83591280,
#    'login': 'andreafought',
#    'display_login': 'andreafought',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/andreafought',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83591280?'},
#   'repo': {'id': 372516647,
#    'name': 'andreafought/IRONAndrea',
#    'url': 'https://api.github.com/repos/andreafought/IRONAndrea'},
#   'payload': {'push_id': 7460609459,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'bbc6a09aa1a05ee847a43dcf9023d156bdece83d',
#    'before': 'a6030ae9ff12a874d083d19242189b25f4aedc6f',
#    'commits': [{'sha': 'bbc6a09aa1a05ee847a43dcf9023d156bdece83d',
#      'author': {'email': 'andreafought@gmail.com', 'name': 'AndreaFought'},
#      'message': 'Add machine_learning  iterations',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/andreafought/IRONAndrea/commits/bbc6a09aa1a05ee847a43dcf9023d156bdece83d'}]},
#   'public': True,
#   'created_at': '2021-07-05T15:48:30Z'},
#  {'id': '17022569412',
#   'type': 'PushEvent',
#   'actor': {'id': 83591280,
#    'login': 'andreafought',
#    'display_login': 'andreafought',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/andreafought',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83591280?'},
#   'repo': {'id': 380792239,
#    'name': 'andreafought/Project',
#    'url': 'https://api.github.com/repos/andreafought/Project'},
#   'payload': {'push_id': 7449118391,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'bde0d3b4650f842b4b895e074b04755981d9044e',
#    'before': 'b3a2e94cf36631f6b3545800549dc042a188c3ad',
#    'commits': [{'sha': 'bde0d3b4650f842b4b895e074b04755981d9044e',
#      'author': {'email': '83591280+andreafought@users.noreply.github.com',
#       'name': 'andreafought'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/andreafought/Project/commits/bde0d3b4650f842b4b895e074b04755981d9044e'}]},
#   'public': True,
#   'created_at': '2021-07-02T22:30:39Z'},
#  {'id': '17021893618',
#   'type': 'PushEvent',
#   'actor': {'id': 83591280,
#    'login': 'andreafought',
#    'display_login': 'andreafought',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/andreafought',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83591280?'},
#   'repo': {'id': 380792239,
#    'name': 'andreafought/Project',
#    'url': 'https://api.github.com/repos/andreafought/Project'},
#   'payload': {'push_id': 7448772209,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'b3a2e94cf36631f6b3545800549dc042a188c3ad',
#    'before': 'fe9f6789ac1e00cffa3b3567fc79372239aa6f41',
#    'commits': [{'sha': 'b3a2e94cf36631f6b3545800549dc042a188c3ad',
#      'author': {'email': '83591280+andreafought@users.noreply.github.com',
#       'name': 'andreafought'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/andreafought/Project/commits/b3a2e94cf36631f6b3545800549dc042a188c3ad'}]},
#   'public': True,
#   'created_at': '2021-07-02T20:49:45Z'},
#  {'id': '17021886506',
#   'type': 'PushEvent',
#   'actor': {'id': 83591280,
#    'login': 'andreafought',
#    'display_login': 'andreafought',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/andreafought',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83591280?'},
#   'repo': {'id': 380792239,
#    'name': 'andreafought/Project',
#    'url': 'https://api.github.com/repos/andreafought/Project'},
#   'payload': {'push_id': 7448768669,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'fe9f6789ac1e00cffa3b3567fc79372239aa6f41',
#    'before': 'f5cd1edf80b5f7c3630f34a8d0e911d312514044',
#    'commits': [{'sha': 'fe9f6789ac1e00cffa3b3567fc79372239aa6f41',
#      'author': {'email': '83591280+andreafought@users.noreply.github.com',
#       'name': 'andreafought'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/andreafought/Project/commits/fe9f6789ac1e00cffa3b3567fc79372239aa6f41'}]},
#   'public': True,
#   'created_at': '2021-07-02T20:48:49Z'},
#  {'id': '17021735186',
#   'type': 'PushEvent',
#   'actor': {'id': 83591280,
#    'login': 'andreafought',
#    'display_login': 'andreafought',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/andreafought',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83591280?'},
#   'repo': {'id': 380792239,
#    'name': 'andreafought/Project',
#    'url': 'https://api.github.com/repos/andreafought/Project'},
#   'payload': {'push_id': 7448691353,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'f5cd1edf80b5f7c3630f34a8d0e911d312514044',
#    'before': '78fa6ed2dc37ab4f264f70196c241e5d32b0cab0',
#    'commits': [{'sha': 'f5cd1edf80b5f7c3630f34a8d0e911d312514044',
#      'author': {'email': '83591280+andreafought@users.noreply.github.com',
#       'name': 'andreafought'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/andreafought/Project/commits/f5cd1edf80b5f7c3630f34a8d0e911d312514044'}]},
#   'public': True,
#   'created_at': '2021-07-02T20:28:52Z'},
#  {'id': '17021731222',
#   'type': 'PushEvent',
#   'actor': {'id': 83591280,
#    'login': 'andreafought',
#    'display_login': 'andreafought',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/andreafought',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83591280?'},
#   'repo': {'id': 380792239,
#    'name': 'andreafought/Project',
#    'url': 'https://api.github.com/repos/andreafought/Project'},
#   'payload': {'push_id': 7448689456,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '78fa6ed2dc37ab4f264f70196c241e5d32b0cab0',
#    'before': '4faab4fc8696c57662f3392347600bbe45375194',
#    'commits': [{'sha': '78fa6ed2dc37ab4f264f70196c241e5d32b0cab0',
#      'author': {'email': '83591280+andreafought@users.noreply.github.com',
#       'name': 'andreafought'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/andreafought/Project/commits/78fa6ed2dc37ab4f264f70196c241e5d32b0cab0'}]},
#   'public': True,
#   'created_at': '2021-07-02T20:28:24Z'},
#  {'id': '17021716032',
#   'type': 'PushEvent',
#   'actor': {'id': 83591280,
#    'login': 'andreafought',
#    'display_login': 'andreafought',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/andreafought',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83591280?'},
#   'repo': {'id': 380792239,
#    'name': 'andreafought/Project',
#    'url': 'https://api.github.com/repos/andreafought/Project'},
#   'payload': {'push_id': 7448681672,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '4faab4fc8696c57662f3392347600bbe45375194',
#    'before': 'f95168a972836aecd0a812caf441c1c5835721cb',
#    'commits': [{'sha': '4faab4fc8696c57662f3392347600bbe45375194',
#      'author': {'email': '83591280+andreafought@users.noreply.github.com',
#       'name': 'andreafought'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/andreafought/Project/commits/4faab4fc8696c57662f3392347600bbe45375194'}]},
#   'public': True,
#   'created_at': '2021-07-02T20:26:30Z'},
#  {'id': '17021660143',
#   'type': 'PushEvent',
#   'actor': {'id': 83591280,
#    'login': 'andreafought',
#    'display_login': 'andreafought',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/andreafought',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83591280?'},
#   'repo': {'id': 380792239,
#    'name': 'andreafought/Project',
#    'url': 'https://api.github.com/repos/andreafought/Project'},
#   'payload': {'push_id': 7448653455,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'f95168a972836aecd0a812caf441c1c5835721cb',
#    'before': 'd6ff3db8deaf5f0d292672a8b66dc16f19b0867c',
#    'commits': [{'sha': 'f95168a972836aecd0a812caf441c1c5835721cb',
#      'author': {'email': '83591280+andreafought@users.noreply.github.com',
#       'name': 'andreafought'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/andreafought/Project/commits/f95168a972836aecd0a812caf441c1c5835721cb'}]},
#   'public': True,
#   'created_at': '2021-07-02T20:19:38Z'},
#  {'id': '17021293409',
#   'type': 'PushEvent',
#   'actor': {'id': 83591280,
#    'login': 'andreafought',
#    'display_login': 'andreafought',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/andreafought',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83591280?'},
#   'repo': {'id': 380792239,
#    'name': 'andreafought/Project',
#    'url': 'https://api.github.com/repos/andreafought/Project'},
#   'payload': {'push_id': 7448473293,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'd6ff3db8deaf5f0d292672a8b66dc16f19b0867c',
#    'before': '463f976dd0937f1548948d9692f84d6c05982f16',
#    'commits': [{'sha': 'd6ff3db8deaf5f0d292672a8b66dc16f19b0867c',
#      'author': {'email': '83591280+andreafought@users.noreply.github.com',
#       'name': 'andreafought'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/andreafought/Project/commits/d6ff3db8deaf5f0d292672a8b66dc16f19b0867c'}]},
#   'public': True,
#   'created_at': '2021-07-02T19:36:24Z'},
#  {'id': '17021243051',
#   'type': 'PushEvent',
#   'actor': {'id': 83591280,
#    'login': 'andreafought',
#    'display_login': 'andreafought',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/andreafought',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83591280?'},
#   'repo': {'id': 380792239,
#    'name': 'andreafought/Project',
#    'url': 'https://api.github.com/repos/andreafought/Project'},
#   'payload': {'push_id': 7448447784,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '463f976dd0937f1548948d9692f84d6c05982f16',
#    'before': '9d899079c8c00f5aa81908949b8b867852dfbfef',
#    'commits': [{'sha': '463f976dd0937f1548948d9692f84d6c05982f16',
#      'author': {'email': '83591280+andreafought@users.noreply.github.com',
#       'name': 'andreafought'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/andreafought/Project/commits/463f976dd0937f1548948d9692f84d6c05982f16'}]},
#   'public': True,
#   'created_at': '2021-07-02T19:30:24Z'},
#  {'id': '17021216820',
#   'type': 'PushEvent',
#   'actor': {'id': 83591280,
#    'login': 'andreafought',
#    'display_login': 'andreafought',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/andreafought',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83591280?'},
#   'repo': {'id': 380792239,
#    'name': 'andreafought/Project',
#    'url': 'https://api.github.com/repos/andreafought/Project'},
#   'payload': {'push_id': 7448434044,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '9d899079c8c00f5aa81908949b8b867852dfbfef',
#    'before': '67390c9373fe529eed390e4bcb812158d2f6b035',
#    'commits': [{'sha': '9d899079c8c00f5aa81908949b8b867852dfbfef',
#      'author': {'email': '83591280+andreafought@users.noreply.github.com',
#       'name': 'andreafought'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/andreafought/Project/commits/9d899079c8c00f5aa81908949b8b867852dfbfef'}]},
#   'public': True,
#   'created_at': '2021-07-02T19:27:35Z'},
#  {'id': '17020025541',
#   'type': 'PushEvent',
#   'actor': {'id': 83591280,
#    'login': 'andreafought',
#    'display_login': 'andreafought',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/andreafought',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83591280?'},
#   'repo': {'id': 380792239,
#    'name': 'andreafought/Project',
#    'url': 'https://api.github.com/repos/andreafought/Project'},
#   'payload': {'push_id': 7447850979,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '67390c9373fe529eed390e4bcb812158d2f6b035',
#    'before': 'dda255ea462eeb3b756dbe7c57fa16422e02c7f6',
#    'commits': [{'sha': '67390c9373fe529eed390e4bcb812158d2f6b035',
#      'author': {'email': '83591280+andreafought@users.noreply.github.com',
#       'name': 'andreafought'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/andreafought/Project/commits/67390c9373fe529eed390e4bcb812158d2f6b035'}]},
#   'public': True,
#   'created_at': '2021-07-02T17:22:57Z'},
#  {'id': '17020006086',
#   'type': 'PushEvent',
#   'actor': {'id': 83591280,
#    'login': 'andreafought',
#    'display_login': 'andreafought',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/andreafought',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83591280?'},
#   'repo': {'id': 380792239,
#    'name': 'andreafought/Project',
#    'url': 'https://api.github.com/repos/andreafought/Project'},
#   'payload': {'push_id': 7447841713,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'dda255ea462eeb3b756dbe7c57fa16422e02c7f6',
#    'before': '5d4af5eb110241da8c129e136aec671c93863079',
#    'commits': [{'sha': 'dda255ea462eeb3b756dbe7c57fa16422e02c7f6',
#      'author': {'email': '83591280+andreafought@users.noreply.github.com',
#       'name': 'andreafought'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/andreafought/Project/commits/dda255ea462eeb3b756dbe7c57fa16422e02c7f6'}]},
#   'public': True,
#   'created_at': '2021-07-02T17:21:06Z'},
#  {'id': '17019995050',
#   'type': 'PushEvent',
#   'actor': {'id': 83591280,
#    'login': 'andreafought',
#    'display_login': 'andreafought',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/andreafought',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83591280?'},
#   'repo': {'id': 380792239,
#    'name': 'andreafought/Project',
#    'url': 'https://api.github.com/repos/andreafought/Project'},
#   'payload': {'push_id': 7447836349,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '5d4af5eb110241da8c129e136aec671c93863079',
#    'before': '50a7ece0e55b6a3b8a3ecf71b91b2b8d14d04097',
#    'commits': [{'sha': '5d4af5eb110241da8c129e136aec671c93863079',
#      'author': {'email': '83591280+andreafought@users.noreply.github.com',
#       'name': 'andreafought'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/andreafought/Project/commits/5d4af5eb110241da8c129e136aec671c93863079'}]},
#   'public': True,
#   'created_at': '2021-07-02T17:20:08Z'},
#  {'id': '17008949285',
#   'type': 'PushEvent',
#   'actor': {'id': 83591280,
#    'login': 'andreafought',
#    'display_login': 'andreafought',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/andreafought',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83591280?'},
#   'repo': {'id': 380792239,
#    'name': 'andreafought/Project',
#    'url': 'https://api.github.com/repos/andreafought/Project'},
#   'payload': {'push_id': 7442434773,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/main',
#    'head': '50a7ece0e55b6a3b8a3ecf71b91b2b8d14d04097',
#    'before': 'cf129a0bb461a6ccd63a0acb10ad530d2d59f7b0',
#    'commits': [{'sha': 'd1ee5492ce26e6d6d3d8ff7f3ad33f57ed2e887b',
#      'author': {'email': 'andreafought@gmail.com', 'name': 'AndreaFought'},
#      'message': 'Update day before presentation push',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/andreafought/Project/commits/d1ee5492ce26e6d6d3d8ff7f3ad33f57ed2e887b'},
#     {'sha': '50a7ece0e55b6a3b8a3ecf71b91b2b8d14d04097',
#      'author': {'email': 'andreafought@gmail.com', 'name': 'AndreaFought'},
#      'message': "Merge branch 'main' of https://github.com/andreafought/Project into main",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/andreafought/Project/commits/50a7ece0e55b6a3b8a3ecf71b91b2b8d14d04097'}]},
#   'public': True,
#   'created_at': '2021-07-01T23:12:24Z'},
#  {'id': '17008843890',
#   'type': 'PushEvent',
#   'actor': {'id': 83591280,
#    'login': 'andreafought',
#    'display_login': 'andreafought',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/andreafought',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83591280?'},
#   'repo': {'id': 380792239,
#    'name': 'andreafought/Project',
#    'url': 'https://api.github.com/repos/andreafought/Project'},
#   'payload': {'push_id': 7442383415,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'cf129a0bb461a6ccd63a0acb10ad530d2d59f7b0',
#    'before': 'c1f816c74d2290113809ec8e4cdec944381af093',
#    'commits': [{'sha': 'cf129a0bb461a6ccd63a0acb10ad530d2d59f7b0',
#      'author': {'email': '83591280+andreafought@users.noreply.github.com',
#       'name': 'andreafought'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/andreafought/Project/commits/cf129a0bb461a6ccd63a0acb10ad530d2d59f7b0'}]},
#   'public': True,
#   'created_at': '2021-07-01T22:58:47Z'},
#  {'id': '17008756198',
#   'type': 'PushEvent',
#   'actor': {'id': 83591280,
#    'login': 'andreafought',
#    'display_login': 'andreafought',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/andreafought',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83591280?'},
#   'repo': {'id': 380792239,
#    'name': 'andreafought/Project',
#    'url': 'https://api.github.com/repos/andreafought/Project'},
#   'payload': {'push_id': 7442339016,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'c1f816c74d2290113809ec8e4cdec944381af093',
#    'before': '088334a6a2ff49222ee1a997986fc01d551e32af',
#    'commits': [{'sha': 'c1f816c74d2290113809ec8e4cdec944381af093',
#      'author': {'email': '83591280+andreafought@users.noreply.github.com',
#       'name': 'andreafought'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/andreafought/Project/commits/c1f816c74d2290113809ec8e4cdec944381af093'}]},
#   'public': True,
#   'created_at': '2021-07-01T22:45:28Z'},
#  {'id': '16998092290',
#   'type': 'PushEvent',
#   'actor': {'id': 83591280,
#    'login': 'andreafought',
#    'display_login': 'andreafought',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/andreafought',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83591280?'},
#   'repo': {'id': 380792239,
#    'name': 'andreafought/Project',
#    'url': 'https://api.github.com/repos/andreafought/Project'},
#   'payload': {'push_id': 7437261657,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '088334a6a2ff49222ee1a997986fc01d551e32af',
#    'before': '96030d278526889f96b8e5e82f3809079deb47e7',
#    'commits': [{'sha': '088334a6a2ff49222ee1a997986fc01d551e32af',
#      'author': {'email': '83591280+andreafought@users.noreply.github.com',
#       'name': 'andreafought'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/andreafought/Project/commits/088334a6a2ff49222ee1a997986fc01d551e32af'}]},
#   'public': True,
#   'created_at': '2021-07-01T09:04:30Z'},
#  {'id': '16991564370',
#   'type': 'PushEvent',
#   'actor': {'id': 83591280,
#    'login': 'andreafought',
#    'display_login': 'andreafought',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/andreafought',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83591280?'},
#   'repo': {'id': 380792239,
#    'name': 'andreafought/Project',
#    'url': 'https://api.github.com/repos/andreafought/Project'},
#   'payload': {'push_id': 7434138207,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '96030d278526889f96b8e5e82f3809079deb47e7',
#    'before': 'a98f5b4d15f18378a44bcdb06778c8243557f8d7',
#    'commits': [{'sha': '96030d278526889f96b8e5e82f3809079deb47e7',
#      'author': {'email': '83591280+andreafought@users.noreply.github.com',
#       'name': 'andreafought'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/andreafought/Project/commits/96030d278526889f96b8e5e82f3809079deb47e7'}]},
#   'public': True,
#   'created_at': '2021-06-30T21:17:39Z'},
#  {'id': '16989790236',
#   'type': 'PushEvent',
#   'actor': {'id': 83591280,
#    'login': 'andreafought',
#    'display_login': 'andreafought',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/andreafought',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83591280?'},
#   'repo': {'id': 380792239,
#    'name': 'andreafought/Project',
#    'url': 'https://api.github.com/repos/andreafought/Project'},
#   'payload': {'push_id': 7433300166,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'a98f5b4d15f18378a44bcdb06778c8243557f8d7',
#    'before': '4b62f0510b4e5cc30add632b2ce11a73921dae62',
#    'commits': [{'sha': 'a98f5b4d15f18378a44bcdb06778c8243557f8d7',
#      'author': {'email': '83591280+andreafought@users.noreply.github.com',
#       'name': 'andreafought'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/andreafought/Project/commits/a98f5b4d15f18378a44bcdb06778c8243557f8d7'}]},
#   'public': True,
#   'created_at': '2021-06-30T18:49:34Z'},
#  {'id': '16987957305',
#   'type': 'PushEvent',
#   'actor': {'id': 83591280,
#    'login': 'andreafought',
#    'display_login': 'andreafought',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/andreafought',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83591280?'},
#   'repo': {'id': 380792239,
#    'name': 'andreafought/Project',
#    'url': 'https://api.github.com/repos/andreafought/Project'},
#   'payload': {'push_id': 7432458920,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '4b62f0510b4e5cc30add632b2ce11a73921dae62',
#    'before': '831619e092d59fe46ada0e79e388dc3437846cb9',
#    'commits': [{'sha': '4b62f0510b4e5cc30add632b2ce11a73921dae62',
#      'author': {'email': '83591280+andreafought@users.noreply.github.com',
#       'name': 'andreafought'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/andreafought/Project/commits/4b62f0510b4e5cc30add632b2ce11a73921dae62'}]},
#   'public': True,
#   'created_at': '2021-06-30T16:27:00Z'},
#  {'id': '16982270086',
#   'type': 'PushEvent',
#   'actor': {'id': 83591280,
#    'login': 'andreafought',
#    'display_login': 'andreafought',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/andreafought',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83591280?'},
#   'repo': {'id': 380792239,
#    'name': 'andreafought/Project',
#    'url': 'https://api.github.com/repos/andreafought/Project'},
#   'payload': {'push_id': 7429754697,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '831619e092d59fe46ada0e79e388dc3437846cb9',
#    'before': 'fc60d7b85463389885730ecc9f00ca20113894eb',
#    'commits': [{'sha': '831619e092d59fe46ada0e79e388dc3437846cb9',
#      'author': {'email': '83591280+andreafought@users.noreply.github.com',
#       'name': 'andreafought'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/andreafought/Project/commits/831619e092d59fe46ada0e79e388dc3437846cb9'}]},
#   'public': True,
#   'created_at': '2021-06-30T10:19:23Z'},
#  {'id': '16980253786',
#   'type': 'PushEvent',
#   'actor': {'id': 83591280,
#    'login': 'andreafought',
#    'display_login': 'andreafought',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/andreafought',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83591280?'},
#   'repo': {'id': 380792239,
#    'name': 'andreafought/Project',
#    'url': 'https://api.github.com/repos/andreafought/Project'},
#   'payload': {'push_id': 7428807810,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'fc60d7b85463389885730ecc9f00ca20113894eb',
#    'before': '8241d89c761d84ed2f4c395846f8ced6877b07d9',
#    'commits': [{'sha': 'fc60d7b85463389885730ecc9f00ca20113894eb',
#      'author': {'email': '83591280+andreafought@users.noreply.github.com',
#       'name': 'andreafought'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/andreafought/Project/commits/fc60d7b85463389885730ecc9f00ca20113894eb'}]},
#   'public': True,
#   'created_at': '2021-06-30T07:56:07Z'},
#  {'id': '16975604646',
#   'type': 'PushEvent',
#   'actor': {'id': 83591280,
#    'login': 'andreafought',
#    'display_login': 'andreafought',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/andreafought',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83591280?'},
#   'repo': {'id': 380792239,
#    'name': 'andreafought/Project',
#    'url': 'https://api.github.com/repos/andreafought/Project'},
#   'payload': {'push_id': 7426454053,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '8241d89c761d84ed2f4c395846f8ced6877b07d9',
#    'before': '76576f5208972be706729a9c6cf34fe4d084b8d8',
#    'commits': [{'sha': '8241d89c761d84ed2f4c395846f8ced6877b07d9',
#      'author': {'email': '83591280+andreafought@users.noreply.github.com',
#       'name': 'andreafought'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/andreafought/Project/commits/8241d89c761d84ed2f4c395846f8ced6877b07d9'}]},
#   'public': True,
#   'created_at': '2021-06-29T22:14:12Z'},
#  {'id': '16968744930',
#   'type': 'PushEvent',
#   'actor': {'id': 83591280,
#    'login': 'andreafought',
#    'display_login': 'andreafought',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/andreafought',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83591280?'},
#   'repo': {'id': 380792239,
#    'name': 'andreafought/Project',
#    'url': 'https://api.github.com/repos/andreafought/Project'},
#   'payload': {'push_id': 7423221868,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '76576f5208972be706729a9c6cf34fe4d084b8d8',
#    'before': '22fe466dfa5e5fa1a95c55593b20697f1a07a678',
#    'commits': [{'sha': '76576f5208972be706729a9c6cf34fe4d084b8d8',
#      'author': {'email': '83591280+andreafought@users.noreply.github.com',
#       'name': 'andreafought'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/andreafought/Project/commits/76576f5208972be706729a9c6cf34fe4d084b8d8'}]},
#   'public': True,
#   'created_at': '2021-06-29T13:49:27Z'},
#  {'id': '16968689321',
#   'type': 'PushEvent',
#   'actor': {'id': 83591280,
#    'login': 'andreafought',
#    'display_login': 'andreafought',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/andreafought',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83591280?'},
#   'repo': {'id': 380792239,
#    'name': 'andreafought/Project',
#    'url': 'https://api.github.com/repos/andreafought/Project'},
#   'payload': {'push_id': 7423196431,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '22fe466dfa5e5fa1a95c55593b20697f1a07a678',
#    'before': 'ab96767dc31e780ca0a2454a05b7f1dc892614ad',
#    'commits': [{'sha': '22fe466dfa5e5fa1a95c55593b20697f1a07a678',
#      'author': {'email': '83591280+andreafought@users.noreply.github.com',
#       'name': 'andreafought'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/andreafought/Project/commits/22fe466dfa5e5fa1a95c55593b20697f1a07a678'}]},
#   'public': True,
#   'created_at': '2021-06-29T13:46:28Z'},
#  {'id': '16965264126',
#   'type': 'PushEvent',
#   'actor': {'id': 83591280,
#    'login': 'andreafought',
#    'display_login': 'andreafought',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/andreafought',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83591280?'},
#   'repo': {'id': 380792239,
#    'name': 'andreafought/Project',
#    'url': 'https://api.github.com/repos/andreafought/Project'},
#   'payload': {'push_id': 7421584685,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'ab96767dc31e780ca0a2454a05b7f1dc892614ad',
#    'before': 'f975b32961eb6886e49391510688093fc9b44c95',
#    'commits': [{'sha': 'ab96767dc31e780ca0a2454a05b7f1dc892614ad',
#      'author': {'email': '83591280+andreafought@users.noreply.github.com',
#       'name': 'andreafought'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/andreafought/Project/commits/ab96767dc31e780ca0a2454a05b7f1dc892614ad'}]},
#   'public': True,
#   'created_at': '2021-06-29T10:05:49Z'},
#  {'id': '16965004413',
#   'type': 'PushEvent',
#   'actor': {'id': 83591280,
#    'login': 'andreafought',
#    'display_login': 'andreafought',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/andreafought',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83591280?'},
#   'repo': {'id': 380792239,
#    'name': 'andreafought/Project',
#    'url': 'https://api.github.com/repos/andreafought/Project'},
#   'payload': {'push_id': 7421459459,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'f975b32961eb6886e49391510688093fc9b44c95',
#    'before': '4c02f82638a3d88787d8f32153907db64a66840c',
#    'commits': [{'sha': 'f975b32961eb6886e49391510688093fc9b44c95',
#      'author': {'email': '83591280+andreafought@users.noreply.github.com',
#       'name': 'andreafought'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/andreafought/Project/commits/f975b32961eb6886e49391510688093fc9b44c95'}]},
#   'public': True,
#   'created_at': '2021-06-29T09:48:26Z'},
#  {'id': '16964516996',
#   'type': 'PushEvent',
#   'actor': {'id': 83591280,
#    'login': 'andreafought',
#    'display_login': 'andreafought',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/andreafought',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83591280?'},
#   'repo': {'id': 380792239,
#    'name': 'andreafought/Project',
#    'url': 'https://api.github.com/repos/andreafought/Project'},
#   'payload': {'push_id': 7421225893,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '4c02f82638a3d88787d8f32153907db64a66840c',
#    'before': 'd300a55182226904f7887d1d8647ceb6cf0fc710',
#    'commits': [{'sha': '4c02f82638a3d88787d8f32153907db64a66840c',
#      'author': {'email': '83591280+andreafought@users.noreply.github.com',
#       'name': 'andreafought'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/andreafought/Project/commits/4c02f82638a3d88787d8f32153907db64a66840c'}]},
#   'public': True,
#   'created_at': '2021-06-29T09:14:55Z'},
#  {'id': '16963491941',
#   'type': 'PushEvent',
#   'actor': {'id': 83591280,
#    'login': 'andreafought',
#    'display_login': 'andreafought',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/andreafought',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83591280?'},
#   'repo': {'id': 380792239,
#    'name': 'andreafought/Project',
#    'url': 'https://api.github.com/repos/andreafought/Project'},
#   'payload': {'push_id': 7420742478,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'd300a55182226904f7887d1d8647ceb6cf0fc710',
#    'before': 'a35b252dbf2f290fd0dc77d40a09b6c32c54bf86',
#    'commits': [{'sha': 'd300a55182226904f7887d1d8647ceb6cf0fc710',
#      'author': {'email': '83591280+andreafought@users.noreply.github.com',
#       'name': 'andreafought'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/andreafought/Project/commits/d300a55182226904f7887d1d8647ceb6cf0fc710'}]},
#   'public': True,
#   'created_at': '2021-06-29T08:05:40Z'}]

# %%
#turn the json into a Data Frame 
pd.DataFrame(response.json())
# Out:
#              id       type                                              actor  \
# 0   17042971853  PushEvent  {'id': 83591280, 'login': 'andreafought', 'dis...
# 1   17022569412  PushEvent  {'id': 83591280, 'login': 'andreafought', 'dis...
# 2   17021893618  PushEvent  {'id': 83591280, 'login': 'andreafought', 'dis...
# 3   17021886506  PushEvent  {'id': 83591280, 'login': 'andreafought', 'dis...
# 4   17021735186  PushEvent  {'id': 83591280, 'login': 'andreafought', 'dis...
# 5   17021731222  PushEvent  {'id': 83591280, 'login': 'andreafought', 'dis...
# 6   17021716032  PushEvent  {'id': 83591280, 'login': 'andreafought', 'dis...
# 7   17021660143  PushEvent  {'id': 83591280, 'login': 'andreafought', 'dis...
# 8   17021293409  PushEvent  {'id': 83591280, 'login': 'andreafought', 'dis...
# 9   17021243051  PushEvent  {'id': 83591280, 'login': 'andreafought', 'dis...
# 10  17021216820  PushEvent  {'id': 83591280, 'login': 'andreafought', 'dis...
# 11  17020025541  PushEvent  {'id': 83591280, 'login': 'andreafought', 'dis...
# 12  17020006086  PushEvent  {'id': 83591280, 'login': 'andreafought', 'dis...
# 13  17019995050  PushEvent  {'id': 83591280, 'login': 'andreafought', 'dis...
# 14  17008949285  PushEvent  {'id': 83591280, 'login': 'andreafought', 'dis...
# 15  17008843890  PushEvent  {'id': 83591280, 'login': 'andreafought', 'dis...
# 16  17008756198  PushEvent  {'id': 83591280, 'login': 'andreafought', 'dis...
# 17  16998092290  PushEvent  {'id': 83591280, 'login': 'andreafought', 'dis...
# 18  16991564370  PushEvent  {'id': 83591280, 'login': 'andreafought', 'dis...
# 19  16989790236  PushEvent  {'id': 83591280, 'login': 'andreafought', 'dis...
# 20  16987957305  PushEvent  {'id': 83591280, 'login': 'andreafought', 'dis...
# 21  16982270086  PushEvent  {'id': 83591280, 'login': 'andreafought', 'dis...
# 22  16980253786  PushEvent  {'id': 83591280, 'login': 'andreafought', 'dis...
# 23  16975604646  PushEvent  {'id': 83591280, 'login': 'andreafought', 'dis...
# 24  16968744930  PushEvent  {'id': 83591280, 'login': 'andreafought', 'dis...
# 25  16968689321  PushEvent  {'id': 83591280, 'login': 'andreafought', 'dis...
# 26  16965264126  PushEvent  {'id': 83591280, 'login': 'andreafought', 'dis...
# 27  16965004413  PushEvent  {'id': 83591280, 'login': 'andreafought', 'dis...
# 28  16964516996  PushEvent  {'id': 83591280, 'login': 'andreafought', 'dis...
# 29  16963491941  PushEvent  {'id': 83591280, 'login': 'andreafought', 'dis...
#
#                                                  repo  \
# 0   {'id': 372516647, 'name': 'andreafought/IRONAn...
# 1   {'id': 380792239, 'name': 'andreafought/Projec...
# 2   {'id': 380792239, 'name': 'andreafought/Projec...
# 3   {'id': 380792239, 'name': 'andreafought/Projec...
# 4   {'id': 380792239, 'name': 'andreafought/Projec...
# 5   {'id': 380792239, 'name': 'andreafought/Projec...
# 6   {'id': 380792239, 'name': 'andreafought/Projec...
# 7   {'id': 380792239, 'name': 'andreafought/Projec...
# 8   {'id': 380792239, 'name': 'andreafought/Projec...
# 9   {'id': 380792239, 'name': 'andreafought/Projec...
# 10  {'id': 380792239, 'name': 'andreafought/Projec...
# 11  {'id': 380792239, 'name': 'andreafought/Projec...
# 12  {'id': 380792239, 'name': 'andreafought/Projec...
# 13  {'id': 380792239, 'name': 'andreafought/Projec...
# 14  {'id': 380792239, 'name': 'andreafought/Projec...
# 15  {'id': 380792239, 'name': 'andreafought/Projec...
# 16  {'id': 380792239, 'name': 'andreafought/Projec...
# 17  {'id': 380792239, 'name': 'andreafought/Projec...
# 18  {'id': 380792239, 'name': 'andreafought/Projec...
# 19  {'id': 380792239, 'name': 'andreafought/Projec...
# 20  {'id': 380792239, 'name': 'andreafought/Projec...
# 21  {'id': 380792239, 'name': 'andreafought/Projec...
# 22  {'id': 380792239, 'name': 'andreafought/Projec...
# 23  {'id': 380792239, 'name': 'andreafought/Projec...
# 24  {'id': 380792239, 'name': 'andreafought/Projec...
# 25  {'id': 380792239, 'name': 'andreafought/Projec...
# 26  {'id': 380792239, 'name': 'andreafought/Projec...
# 27  {'id': 380792239, 'name': 'andreafought/Projec...
# 28  {'id': 380792239, 'name': 'andreafought/Projec...
# 29  {'id': 380792239, 'name': 'andreafought/Projec...
#
#                                               payload  public  \
# 0   {'push_id': 7460609459, 'size': 1, 'distinct_s...    True
# 1   {'push_id': 7449118391, 'size': 1, 'distinct_s...    True
# 2   {'push_id': 7448772209, 'size': 1, 'distinct_s...    True
# 3   {'push_id': 7448768669, 'size': 1, 'distinct_s...    True
# 4   {'push_id': 7448691353, 'size': 1, 'distinct_s...    True
# 5   {'push_id': 7448689456, 'size': 1, 'distinct_s...    True
# 6   {'push_id': 7448681672, 'size': 1, 'distinct_s...    True
# 7   {'push_id': 7448653455, 'size': 1, 'distinct_s...    True
# 8   {'push_id': 7448473293, 'size': 1, 'distinct_s...    True
# 9   {'push_id': 7448447784, 'size': 1, 'distinct_s...    True
# 10  {'push_id': 7448434044, 'size': 1, 'distinct_s...    True
# 11  {'push_id': 7447850979, 'size': 1, 'distinct_s...    True
# 12  {'push_id': 7447841713, 'size': 1, 'distinct_s...    True
# 13  {'push_id': 7447836349, 'size': 1, 'distinct_s...    True
# 14  {'push_id': 7442434773, 'size': 2, 'distinct_s...    True
# 15  {'push_id': 7442383415, 'size': 1, 'distinct_s...    True
# 16  {'push_id': 7442339016, 'size': 1, 'distinct_s...    True
# 17  {'push_id': 7437261657, 'size': 1, 'distinct_s...    True
# 18  {'push_id': 7434138207, 'size': 1, 'distinct_s...    True
# 19  {'push_id': 7433300166, 'size': 1, 'distinct_s...    True
# 20  {'push_id': 7432458920, 'size': 1, 'distinct_s...    True
# 21  {'push_id': 7429754697, 'size': 1, 'distinct_s...    True
# 22  {'push_id': 7428807810, 'size': 1, 'distinct_s...    True
# 23  {'push_id': 7426454053, 'size': 1, 'distinct_s...    True
# 24  {'push_id': 7423221868, 'size': 1, 'distinct_s...    True
# 25  {'push_id': 7423196431, 'size': 1, 'distinct_s...    True
# 26  {'push_id': 7421584685, 'size': 1, 'distinct_s...    True
# 27  {'push_id': 7421459459, 'size': 1, 'distinct_s...    True
# 28  {'push_id': 7421225893, 'size': 1, 'distinct_s...    True
# 29  {'push_id': 7420742478, 'size': 1, 'distinct_s...    True
#
#               created_at
# 0   2021-07-05T15:48:30Z
# 1   2021-07-02T22:30:39Z
# 2   2021-07-02T20:49:45Z
# 3   2021-07-02T20:48:49Z
# 4   2021-07-02T20:28:52Z
# 5   2021-07-02T20:28:24Z
# 6   2021-07-02T20:26:30Z
# 7   2021-07-02T20:19:38Z
# 8   2021-07-02T19:36:24Z
# 9   2021-07-02T19:30:24Z
# 10  2021-07-02T19:27:35Z
# 11  2021-07-02T17:22:57Z
# 12  2021-07-02T17:21:06Z
# 13  2021-07-02T17:20:08Z
# 14  2021-07-01T23:12:24Z
# 15  2021-07-01T22:58:47Z
# 16  2021-07-01T22:45:28Z
# 17  2021-07-01T09:04:30Z
# 18  2021-06-30T21:17:39Z
# 19  2021-06-30T18:49:34Z
# 20  2021-06-30T16:27:00Z
# 21  2021-06-30T10:19:23Z
# 22  2021-06-30T07:56:07Z
# 23  2021-06-29T22:14:12Z
# 24  2021-06-29T13:49:27Z
# 25  2021-06-29T13:46:28Z
# 26  2021-06-29T10:05:49Z
# 27  2021-06-29T09:48:26Z
# 28  2021-06-29T09:14:55Z
# 29  2021-06-29T08:05:40Z

# %%
#unpack the json using  pd.json_normalize()

# %% [markdown]
# ### Intenational Space Station
#
# Docs here: http://open-notify.org/Open-Notify-API/ISS-Location-Now/

# %%
# Make a get request to get the latest position of the international space station from the opennotify api.
response = requests.get('http://api.open-notify.org/iss-now.json')
# Print the status code of the response.
response.json()
# Out:
# {'message': 'success',
#  'timestamp': 1626189217,
#  'iss_position': {'latitude': '8.9511', 'longitude': '-135.3573'}}

# %%
# when was the last time it was over your house?

coordinates = {"lat":41.395017, "lon":2.153201,"n":10}
response = requests.get("http://api.open-notify.org/iss-pass.json",params=coordinates)
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'message': 'success',
#  'request': {'altitude': 100,
#   'datetime': 1626189258,
#   'latitude': 41.395017,
#   'longitude': 2.153201,
#   'passes': 10},
#  'response': [{'duration': 397, 'risetime': 1626203770},
#   {'duration': 647, 'risetime': 1626209411},
#   {'duration': 628, 'risetime': 1626215238},
#   {'duration': 575, 'risetime': 1626221124},
#   {'duration': 610, 'risetime': 1626226973},
#   {'duration': 654, 'risetime': 1626232781},
#   {'duration': 517, 'risetime': 1626238630},
#   {'duration': 142, 'risetime': 1626287481},
#   {'duration': 625, 'risetime': 1626292993},
#   {'duration': 643, 'risetime': 1626298789}]}

# %%
#find out the date and time from the timestamp
from datetime import datetime
datetime.fromtimestamp(1626189258)
# Out:
# datetime.datetime(2021, 7, 13, 17, 14, 18)

# %%
pd.to_datetime(1626189258, unit="s")
# Out:
# Timestamp('2021-07-13 15:14:18')

# %% [markdown]
# ## OpenWeatherMap API
#
# A nice person wrote a Python wrapper, which can be found here: https://github.com/csparpa/pyowm
#
# `import sys
# !{sys.executable} -m pip install pyowm`

# %% [markdown]
# Create an account here: https://home.openweathermap.org/users/sign_up
#
# Then Sign in and go to the "Keys" tab.

# %%
from pyowm import OWM
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-27-d6fe075b7289> in <module>
# ----> 1 from pyowm import OWM
#
# ModuleNotFoundError: No module named 'pyowm'

# %%
# Search for current weather in Bedford and get details

# %%
# Check the sunset time today in Barcelona or Berlin

# %% [markdown]
# ### Sky scanner API
#
# Create an account at RapidAPI and "subscribe" to the sky scanner API: https://rapidapi.com/skyscanner/api/skyscanner-flight-search

# %%
# use RapidAPI to create the request

# %%
# passing headers and parameters to the request just assembles an url:

# %% [markdown]
# To know the parameters we need to be able to call information properly from an API we should look first at its documentation. From the documentation, how would you query the prices for the flights from San Francisco to New York City on 2020/12/12?
